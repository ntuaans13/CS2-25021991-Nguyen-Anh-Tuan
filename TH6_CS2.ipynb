# %%
#W6A1
a = list(map(int, input().split()))
ans = []
for x in a:
    if(not(x in ans)):
        ans.append(x)

print(ans)
# Out:
# [3, 7, 123]

# %%
#W6A2
a = list(map(int, input().split()))
for i in range(1, len(a)):
    a[i] += a[i - 1]

print(a)
# Out:
# [1, 3, 6, 10, 15]
